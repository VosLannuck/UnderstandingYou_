# %%
# !git clone https://github.com/VosLannuck/UnderstandingYou_
# %cd UnderstandingYou_
# Out:
# Cloning into 'UnderstandingYou_'...
# remote: Enumerating objects: 1377, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 1377 (delta 148), reused 244 (delta 148), pack-reused 1133
# Receiving objects: 100% (1377/1377), 64.81 MiB | 30.36 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/UnderstandingYou_

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.7.2 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 2.3 MB/s eta 0:00:00
# Collecting mlflow==2.8.1 (from -r requirements.txt (line 2))
#   Downloading mlflow-2.8.1-py3-none-any.whl (19.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 3.2 MB/s eta 0:00:00
# Collecting numpy==1.24.3 (from -r requirements.txt (line 3))
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 3.6 MB/s eta 0:00:00
# Collecting omegaconf==2.3.0 (from -r requirements.txt (line 4))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.3 MB/s eta 0:00:00
# Collecting pandas==2.0.3 (from -r requirements.txt (line 5))
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 4.5 MB/s eta 0:00:00
# Collecting Pillow==10.1.0 (from -r requirements.txt (line 6))
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.5 MB/s eta 0:00:00
# Collecting ray==2.8.1 (from -r requirements.txt (line 7))
#   Downloading ray-2.8.1-cp310-cp310-manylinux2014_x86_64.whl (62.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (1.11.4)
# Collecting torch==2.1.1 (from -r requirements.txt (line 9))
#   Downloading torch-2.1.1-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (1.5.1)
# Collecting torchvision==0.16.1 (from -r requirements.txt (line 11))
#   Downloading torchvision-0.16.1-cp310-cp310-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 13.9 MB/s eta 0:00:00
# Collecting tqdm==4.65.0 (from -r requirements.txt (line 12))
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 11.2 MB/s eta 0:00:00
# Collecting optuna==3.5.0 (from -r requirements.txt (line 13))
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 15.2 MB/s eta 0:00:00
# Collecting tensorboardX==2.5.0 (from -r requirements.txt (line 14))
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (23.2)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib==3.7.2->-r requirements.txt (line 1))
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.2.1)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.31.0)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 14.1 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.2.5)
# Collecting querystring-parser<2 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.0.23)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (10.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.5.1)
# Collecting gunicorn<22 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.1.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf==2.3.0->-r requirements.txt (line 4))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tzdata>=2022.1 (from pandas==2.0.3->-r requirements.txt (line 5))
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 13.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 14.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 14.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (2.1.0)
# Collecting colorlog (from optuna==3.5.0->-r requirements.txt (line 13))
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorboardX==2.5.0->-r requirements.txt (line 14)) (1.16.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 33.9 MB/s eta 0:00:00
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow==2.8.1->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow==2.8.1->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow==2.8.1->-r requirements.txt (line 2)) (2.1.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.8.1->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow==2.8.1->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.8.1->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.8.1->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.8.1->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (0.15.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.1->-r requirements.txt (line 9)) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=627286b617b072af8615b5975314ffd7c8076e7c11adfd04717d73b756d312cb
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, tzdata, tqdm, smmap, querystring-parser, pyparsing, Pillow, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, Mako, importlib-metadata, gunicorn, colorlog, tensorboardX, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb, docker, databricks-cli, alembic, optuna, nvidia-cusolver-cu12, matplotlib, gitpython, torch, ray, mlflow, torchvision
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0+cu121
#     Uninstalling torchvision-0.16.0+cu121:
#       Successfully uninstalled torchvision-0.16.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# Successfully installed Mako-1.3.0 Pillow-10.1.0 alembic-1.13.1 antlr4-python3-runtime-4.9.3 colorlog-6.8.0 databricks-cli-0.18.0 docker-6.1.3 gitdb-4.0.11 gitpython-3.1.40 gunicorn-21.2.0 importlib-metadata-6.11.0 matplotlib-3.7.2 mlflow-2.8.1 numpy-1.24.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 optuna-3.5.0 pandas-2.0.3 pyparsing-3.0.9 querystring-parser-1.2.4 ray-2.8.1 smmap-5.0.1 tensorboardX-2.5 torch-2.1.1 torchvision-0.16.1 tqdm-4.65.0 tzdata-2023.4

# %%
# !python HyperparamsMain.py -m="vanilla_resnet"
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 149MB/s]
# 2023-12-30 04:45:16,457	INFO worker.py:1673 -- Started a local Ray instance.
# 2023-12-30 04:45:18,595	INFO tune.py:220 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2023-12-30 04:45:18,597	INFO tune.py:595 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# [I 2023-12-30 04:45:18,618] A new study created in memory with name: optuna
# ╭────────────────────────────────────────────────────────────────────────────╮
# │ Configuration for experiment     objective_optimizer_2023-12-30_04-45-12   │
# ├────────────────────────────────────────────────────────────────────────────┤
# │ Search algorithm                 SearchGenerator                           │
# │ Scheduler                        FIFOScheduler                             │
# │ Number of trials                 30                                        │
# ╰────────────────────────────────────────────────────────────────────────────╯
#
# View detailed results here: /root/ray_results/objective_optimizer_2023-12-30_04-45-12
# To visualize your results with TensorBoard, run: `tensorboard --logdir /root/ray_results/objective_optimizer_2023-12-30_04-45-12`
#
# Trial status: 1 PENDING
# Current time: 2023-12-30 04:45:19. Total running time: 0s
# Logical resource usage: 0/2 CPUs, 0/1 GPUs
# ╭───────────────────────────────────────────────────────╮
# │ Trial name                     status              lr │
# ├───────────────────────────────────────────────────────┤
# │ objective_optimizer_00c1eb26   PENDING    0.000417216 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_00c1eb26 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_00c1eb26 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00042 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 0.9928, TrainAcc : 0.5838
# (objective_optimizer pid=2839) ValLoss : 9.6392, ValAcc : 0.5667
#  10%|█         | 1/10 [00:12<01:52, 12.51s/it]
#
# Trial status: 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:45:49. Total running time: 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=9.639201800028482 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status              lr     iter     total time (s)     loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_00c1eb26   RUNNING    0.000417216        1            13.7375   9.6392   0.566667 │
# │ objective_optimizer_c66de804   PENDING    0.00345513                                                  │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6395, TrainAcc : 0.6648
# (objective_optimizer pid=2839) ValLoss : 11.5697, ValAcc : 0.5833
#  20%|██        | 2/10 [00:22<01:27, 10.90s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.5815, TrainAcc : 0.6955
# (objective_optimizer pid=2839) ValLoss : 0.9529, ValAcc : 0.6111
#  30%|███       | 3/10 [00:31<01:11, 10.21s/it]
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.5820, TrainAcc : 0.7053
# (objective_optimizer pid=2839) ValLoss : 0.8926, ValAcc : 0.6611
#  40%|████      | 4/10 [00:41<01:01, 10.17s/it]
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.5836, TrainAcc : 0.6969
# (objective_optimizer pid=2839) ValLoss : 0.6022, ValAcc : 0.7278
#  50%|█████     | 5/10 [00:51<00:50, 10.03s/it]
# Trial status: 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:46:19. Total running time: 1min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.6022350788116455 and params={'lr': 0.0004172163974077716}
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status              lr     iter     total time (s)       loss        acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_00c1eb26   RUNNING    0.000417216        5            52.7696   0.602235   0.727778 │
# │ objective_optimizer_c66de804   PENDING    0.00345513                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.5991, TrainAcc : 0.7067
# (objective_optimizer pid=2839) ValLoss : 0.6048, ValAcc : 0.6944
#  60%|██████    | 6/10 [01:00<00:39,  9.79s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.5567, TrainAcc : 0.7263
# (objective_optimizer pid=2839) ValLoss : 0.5835, ValAcc : 0.7000
#  70%|███████   | 7/10 [01:10<00:29,  9.89s/it]
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5765, TrainAcc : 0.7025
# (objective_optimizer pid=2839) ValLoss : 0.7253, ValAcc : 0.6444
#  80%|████████  | 8/10 [01:20<00:19,  9.90s/it]
# Trial status: 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:46:49. Total running time: 1min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.7252956827481588 and params={'lr': 0.0004172163974077716}
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status              lr     iter     total time (s)       loss        acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_00c1eb26   RUNNING    0.000417216        8            82.0875   0.725296   0.644444 │
# │ objective_optimizer_c66de804   PENDING    0.00345513                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.5528, TrainAcc : 0.7207
# (objective_optimizer pid=2839) ValLoss : 0.5924, ValAcc : 0.7056
#  90%|█████████ | 9/10 [01:30<00:09,  9.68s/it]
#
# Trial objective_optimizer_00c1eb26 completed after 10 iterations at 2023-12-30 04:47:07. Total running time: 1min 48s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_00c1eb26 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              10.0692 │
# │ time_total_s                                  101.351 │
# │ training_iteration                                 10 │
# │ acc                                           0.69444 │
# │ loss                                           0.5925 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_c66de804 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_c66de804 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00346 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5693, TrainAcc : 0.7165
# (objective_optimizer pid=2839) ValLoss : 0.5925, ValAcc : 0.6944
# 100%|██████████| 10/10 [01:40<00:00, 10.02s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 1.3634, TrainAcc : 0.5559
# (objective_optimizer pid=2839) ValLoss : 316.4815, ValAcc : 0.5000
#  10%|█         | 1/10 [00:10<01:31, 10.22s/it]
#
# Trial status: 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:47:19. Total running time: 2min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)         loss        acc │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_c66de804   RUNNING      0.00345513         1            11.0691   316.481      0.5      │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351      0.592503   0.694444 │
# │ objective_optimizer_a5f78fcb   PENDING      0.00780373                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.7071, TrainAcc : 0.6271
# (objective_optimizer pid=2839) ValLoss : 4.5259, ValAcc : 0.4889
#  20%|██        | 2/10 [00:19<01:15,  9.50s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.6386, TrainAcc : 0.6969
# (objective_optimizer pid=2839) ValLoss : 2.8959, ValAcc : 0.6167
#  30%|███       | 3/10 [00:29<01:08,  9.79s/it]
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.5999, TrainAcc : 0.6760
# (objective_optimizer pid=2839) ValLoss : 1.6845, ValAcc : 0.6667
#  40%|████      | 4/10 [00:39<00:59,  9.97s/it]
# Trial status: 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:47:49. Total running time: 2min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_c66de804   RUNNING      0.00345513         4            40.4365   1.68451    0.666667 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_a5f78fcb   PENDING      0.00780373                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.6332, TrainAcc : 0.6662
# (objective_optimizer pid=2839) ValLoss : 0.7530, ValAcc : 0.6889
#  50%|█████     | 5/10 [00:48<00:48,  9.64s/it]
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.6175, TrainAcc : 0.6844
# (objective_optimizer pid=2839) ValLoss : 0.6212, ValAcc : 0.7000
#  60%|██████    | 6/10 [00:58<00:39,  9.83s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.6074, TrainAcc : 0.6969
# (objective_optimizer pid=2839) ValLoss : 0.5897, ValAcc : 0.7167
#  70%|███████   | 7/10 [01:09<00:29,  9.94s/it]
# Trial status: 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:48:19. Total running time: 3min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c66de804 with loss=0.5897122621536255 and params={'lr': 0.0034551297152949044}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_c66de804   RUNNING      0.00345513         7            69.8563   0.589712   0.716667 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_a5f78fcb   PENDING      0.00780373                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.6503, TrainAcc : 0.6564
# (objective_optimizer pid=2839) ValLoss : 0.6159, ValAcc : 0.6722
#  80%|████████  | 8/10 [01:18<00:19,  9.69s/it]
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.6177, TrainAcc : 0.6760
# (objective_optimizer pid=2839) ValLoss : 0.6323, ValAcc : 0.6556
#  90%|█████████ | 9/10 [01:28<00:09,  9.81s/it]
#
# Trial objective_optimizer_c66de804 completed after 10 iterations at 2023-12-30 04:48:46. Total running time: 3min 27s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_c66de804 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              10.1634 │
# │ time_total_s                                  99.2216 │
# │ training_iteration                                 10 │
# │ acc                                              0.65 │
# │ loss                                          0.67944 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_a5f78fcb started with configuration:
# ╭──────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_a5f78fcb config            │
# ├──────────────────────────────────────────────────────┤
# │ lr                                            0.0078 │
# ╰──────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5644, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.6794, ValAcc : 0.6500
# 100%|██████████| 10/10 [01:38<00:00,  9.84s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:48:49. Total running time: 3min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5f78fcb   RUNNING      0.00780373                                                    │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_21a8c299   PENDING      0.00100933                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 1.2314, TrainAcc : 0.5810
# (objective_optimizer pid=2839) ValLoss : 808981.8750, ValAcc : 0.5000
#  10%|█         | 1/10 [00:09<01:28,  9.80s/it]
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6469, TrainAcc : 0.6732
# (objective_optimizer pid=2839) ValLoss : 429.1051, ValAcc : 0.4944
#  20%|██        | 2/10 [00:19<01:17,  9.66s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.6374, TrainAcc : 0.6732
# (objective_optimizer pid=2839) ValLoss : 4.2638, ValAcc : 0.6444
#  30%|███       | 3/10 [00:29<01:09,  9.88s/it]
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:49:19. Total running time: 4min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5f78fcb   RUNNING      0.00780373         3            30.4158   4.26381    0.644444 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_21a8c299   PENDING      0.00100933                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.6928, TrainAcc : 0.6872
# (objective_optimizer pid=2839) ValLoss : 0.6185, ValAcc : 0.6889
#  40%|████      | 4/10 [00:39<00:59,  9.89s/it]
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.6854, TrainAcc : 0.6592
# (objective_optimizer pid=2839) ValLoss : 0.6551, ValAcc : 0.6000
#  50%|█████     | 5/10 [00:48<00:48,  9.74s/it]
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.7860, TrainAcc : 0.6243
# (objective_optimizer pid=2839) ValLoss : 1.2827, ValAcc : 0.5333
#  60%|██████    | 6/10 [00:59<00:40, 10.14s/it]
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:49:49. Total running time: 4min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5f78fcb   RUNNING      0.00780373         6            60.71     1.28274    0.533333 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_21a8c299   PENDING      0.00100933                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.6298, TrainAcc : 0.6885
# (objective_optimizer pid=2839) ValLoss : 0.5993, ValAcc : 0.7000
#  70%|███████   | 7/10 [01:10<00:31, 10.39s/it]
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.6099, TrainAcc : 0.6983
# (objective_optimizer pid=2839) ValLoss : 3.8045, ValAcc : 0.5722
#  80%|████████  | 8/10 [01:19<00:20, 10.02s/it]
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.6496, TrainAcc : 0.6899
# (objective_optimizer pid=2839) ValLoss : 0.8827, ValAcc : 0.6333
#  90%|█████████ | 9/10 [01:30<00:10, 10.06s/it]
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:50:19. Total running time: 5min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5f78fcb   RUNNING      0.00780373         9            90.9712   0.882692   0.633333 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_21a8c299   PENDING      0.00100933                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.6095, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.7682, ValAcc : 0.6889
# 100%|██████████| 10/10 [01:40<00:00, 10.03s/it]
#
# Trial objective_optimizer_a5f78fcb completed after 10 iterations at 2023-12-30 04:50:28. Total running time: 5min 9s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_a5f78fcb result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              10.1705 │
# │ time_total_s                                  101.142 │
# │ training_iteration                                 10 │
# │ acc                                           0.68889 │
# │ loss                                          0.76817 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_21a8c299 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_21a8c299 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00101 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 1.0431, TrainAcc : 0.5992
# (objective_optimizer pid=2839) ValLoss : 57.0589, ValAcc : 0.5000
#  10%|█         | 1/10 [00:09<01:28,  9.85s/it]
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6268, TrainAcc : 0.6802
# (objective_optimizer pid=2839) ValLoss : 90.4055, ValAcc : 0.5000
#  20%|██        | 2/10 [00:19<01:17,  9.73s/it]
#
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:50:49. Total running time: 5min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)        loss        acc │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_21a8c299   RUNNING      0.00100933         2            20.3696   90.4055     0.5      │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351     0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216    0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142     0.768166   0.688889 │
# │ objective_optimizer_24dae463   PENDING      0.000274307                                                    │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.6022, TrainAcc : 0.6830
# (objective_optimizer pid=2839) ValLoss : 5.5553, ValAcc : 0.5278
#  30%|███       | 3/10 [00:29<01:09,  9.92s/it]
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.6046, TrainAcc : 0.6913
# (objective_optimizer pid=2839) ValLoss : 1.5923, ValAcc : 0.6833
#  40%|████      | 4/10 [00:39<00:59,  9.92s/it]
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.5819, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.6491, ValAcc : 0.6944
#  50%|█████     | 5/10 [00:48<00:48,  9.74s/it]
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:51:19. Total running time: 6min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_21a8c299   RUNNING      0.00100933         5            49.8595   0.649051   0.694444 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_24dae463   PENDING      0.000274307                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.6128, TrainAcc : 0.7095
# (objective_optimizer pid=2839) ValLoss : 0.6205, ValAcc : 0.7000
#  60%|██████    | 6/10 [00:59<00:39,  9.89s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.5853, TrainAcc : 0.7039
# (objective_optimizer pid=2839) ValLoss : 0.6139, ValAcc : 0.6889
#  70%|███████   | 7/10 [01:09<00:29,  9.99s/it]
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5649, TrainAcc : 0.7095
# (objective_optimizer pid=2839) ValLoss : 0.6095, ValAcc : 0.6667
#  80%|████████  | 8/10 [01:18<00:19,  9.75s/it]
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:51:49. Total running time: 6min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_21a8c299   RUNNING      0.00100933         8            79.4687   0.609478   0.666667 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_24dae463   PENDING      0.000274307                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.5767, TrainAcc : 0.6858
# (objective_optimizer pid=2839) ValLoss : 0.5938, ValAcc : 0.7000
#  90%|█████████ | 9/10 [01:28<00:09,  9.87s/it]
#
# Trial objective_optimizer_21a8c299 completed after 10 iterations at 2023-12-30 04:52:08. Total running time: 6min 49s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_21a8c299 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              10.2395 │
# │ time_total_s                                  99.8428 │
# │ training_iteration                                 10 │
# │ acc                                           0.67778 │
# │ loss                                          0.63185 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_24dae463 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_24dae463 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00027 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5452, TrainAcc : 0.7165
# (objective_optimizer pid=2839) ValLoss : 0.6318, ValAcc : 0.6778
# 100%|██████████| 10/10 [01:38<00:00,  9.90s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 0.7523, TrainAcc : 0.6508
# (objective_optimizer pid=2839) ValLoss : 0.7289, ValAcc : 0.5389
#  10%|█         | 1/10 [00:08<01:20,  8.98s/it]
#
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:52:19. Total running time: 7min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_24dae463   RUNNING      0.000274307        1            9.86901   0.728943   0.538889 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10          101.351     0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10           99.2216    0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10          101.142     0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10           99.8428    0.631848   0.677778 │
# │ objective_optimizer_70d8affe   PENDING      0.00246716                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6086, TrainAcc : 0.6997
# (objective_optimizer pid=2839) ValLoss : 1.2907, ValAcc : 0.5111
#  20%|██        | 2/10 [00:18<01:16,  9.50s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.5899, TrainAcc : 0.6941
# (objective_optimizer pid=2839) ValLoss : 0.7177, ValAcc : 0.6722
#  30%|███       | 3/10 [00:28<01:07,  9.65s/it]
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.5711, TrainAcc : 0.7053
# (objective_optimizer pid=2839) ValLoss : 0.7616, ValAcc : 0.6778
#  40%|████      | 4/10 [00:37<00:56,  9.34s/it]
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:52:49. Total running time: 7min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_24dae463   RUNNING      0.000274307        4            38.4217   0.76162    0.677778 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_70d8affe   PENDING      0.00246716                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.5515, TrainAcc : 0.7360
# (objective_optimizer pid=2839) ValLoss : 0.6664, ValAcc : 0.6667
#  50%|█████     | 5/10 [00:47<00:47,  9.55s/it]
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.5697, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.6624, ValAcc : 0.6722
#  60%|██████    | 6/10 [00:57<00:38,  9.72s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.5237, TrainAcc : 0.7207
# (objective_optimizer pid=2839) ValLoss : 0.6021, ValAcc : 0.7278
#  70%|███████   | 7/10 [01:06<00:28,  9.43s/it]
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:53:19. Total running time: 8min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 00c1eb26 with loss=0.5925026337305704 and params={'lr': 0.0004172163974077716}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_24dae463   RUNNING      0.000274307        7            67.2181   0.60207    0.727778 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_70d8affe   PENDING      0.00246716                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5742, TrainAcc : 0.7123
# (objective_optimizer pid=2839) ValLoss : 0.5823, ValAcc : 0.7222
#  80%|████████  | 8/10 [01:16<00:19,  9.59s/it]
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.5343, TrainAcc : 0.7221
# (objective_optimizer pid=2839) ValLoss : 0.5636, ValAcc : 0.7333
#  90%|█████████ | 9/10 [01:26<00:09,  9.71s/it]
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5860, TrainAcc : 0.7123
# (objective_optimizer pid=2839) ValLoss : 0.5770, ValAcc : 0.7167
#
# Trial objective_optimizer_24dae463 completed after 10 iterations at 2023-12-30 04:53:44. Total running time: 8min 25s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_24dae463 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              8.83291 │
# │ time_total_s                                  95.9587 │
# │ training_iteration                                 10 │
# │ acc                                           0.71667 │
# │ loss                                          0.57696 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_70d8affe started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_70d8affe config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00247 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [01:35<00:00,  9.51s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:53:50. Total running time: 8min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 24dae463 with loss=0.576958974202474 and params={'lr': 0.00027430713819744996}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_70d8affe   RUNNING      0.00246716                                                    │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# │ objective_optimizer_394c66c8   PENDING      0.000270711                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 1.2685, TrainAcc : 0.5587
# (objective_optimizer pid=2839) ValLoss : 4202.1395, ValAcc : 0.5000
#  10%|█         | 1/10 [00:10<01:31, 10.18s/it]
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6350, TrainAcc : 0.6508
# (objective_optimizer pid=2839) ValLoss : 94.8815, ValAcc : 0.5000
#  20%|██        | 2/10 [00:20<01:21, 10.16s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.6788, TrainAcc : 0.6648
# (objective_optimizer pid=2839) ValLoss : 9.5680, ValAcc : 0.5000
#  30%|███       | 3/10 [00:29<01:08,  9.85s/it]
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:54:20. Total running time: 9min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 24dae463 with loss=0.576958974202474 and params={'lr': 0.00027430713819744996}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_70d8affe   RUNNING      0.00246716         3            30.8407   9.568      0.5      │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# │ objective_optimizer_394c66c8   PENDING      0.000270711                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.6610, TrainAcc : 0.6830
# (objective_optimizer pid=2839) ValLoss : 1.2291, ValAcc : 0.5278
#  40%|████      | 4/10 [00:39<00:59,  9.88s/it]
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.7296, TrainAcc : 0.6550
# (objective_optimizer pid=2839) ValLoss : 0.7185, ValAcc : 0.6111
#  50%|█████     | 5/10 [00:49<00:49,  9.99s/it]
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.6729, TrainAcc : 0.6704
# (objective_optimizer pid=2839) ValLoss : 16.4237, ValAcc : 0.5167
#  60%|██████    | 6/10 [00:59<00:39,  9.94s/it]
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:54:50. Total running time: 9min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 24dae463 with loss=0.576958974202474 and params={'lr': 0.00027430713819744996}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)        loss        acc │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_70d8affe   RUNNING      0.00246716         6            60.7751   16.4237     0.516667 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351     0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216    0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142     0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428    0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587    0.576959   0.716667 │
# │ objective_optimizer_394c66c8   PENDING      0.000270711                                                    │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.6089, TrainAcc : 0.6885
# (objective_optimizer pid=2839) ValLoss : 0.6858, ValAcc : 0.6000
#  70%|███████   | 7/10 [01:09<00:29,  9.87s/it]
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5730, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 1.0654, ValAcc : 0.6889
#  80%|████████  | 8/10 [01:19<00:19,  9.97s/it]
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.6244, TrainAcc : 0.6899
# (objective_optimizer pid=2839) ValLoss : 0.6944, ValAcc : 0.5778
#  90%|█████████ | 9/10 [01:29<00:09,  9.99s/it]
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 04:55:20. Total running time: 10min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 24dae463 with loss=0.576958974202474 and params={'lr': 0.00027430713819744996}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_70d8affe   RUNNING      0.00246716         9            90.7191   0.694396   0.577778 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# │ objective_optimizer_394c66c8   PENDING      0.000270711                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_70d8affe completed after 10 iterations at 2023-12-30 04:55:24. Total running time: 10min 5s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_70d8affe result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              9.68867 │
# │ time_total_s                                  100.408 │
# │ training_iteration                                 10 │
# │ acc                                           0.69444 │
# │ loss                                          0.64663 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_394c66c8 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_394c66c8 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00027 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.6198, TrainAcc : 0.6844
# (objective_optimizer pid=2839) ValLoss : 0.6466, ValAcc : 0.6944
# 100%|██████████| 10/10 [01:39<00:00,  9.94s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# ...
# │ objective_optimizer_5a767db4   RUNNING      0.000317483        5            50.4673   0.741646   0.644444 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# │ objective_optimizer_7ca5815a   PENDING      0.000305479                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 23 more TERMINATED
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.5515, TrainAcc : 0.6997
# (objective_optimizer pid=2839) ValLoss : 0.6526, ValAcc : 0.6611
#  60%|██████    | 6/10 [00:59<00:39,  9.96s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.5778, TrainAcc : 0.7123
# (objective_optimizer pid=2839) ValLoss : 0.6046, ValAcc : 0.6667
#  70%|███████   | 7/10 [01:08<00:29,  9.73s/it]
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5538, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.5931, ValAcc : 0.7167
#  80%|████████  | 8/10 [01:18<00:19,  9.84s/it]
# Trial status: 28 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:33:24. Total running time: 48min 5s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c612c672 with loss=0.5393751760323843 and params={'lr': 0.00032537224885116194}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_5a767db4   RUNNING      0.000317483        8            79.886    0.593137   0.716667 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# │ objective_optimizer_7ca5815a   PENDING      0.000305479                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 23 more TERMINATED
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.5612, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.5700, ValAcc : 0.7389
#  90%|█████████ | 9/10 [01:28<00:09,  9.95s/it]
#
# Trial objective_optimizer_5a767db4 completed after 10 iterations at 2023-12-30 05:33:36. Total running time: 48min 17s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_5a767db4 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              9.05558 │
# │ time_total_s                                   99.126 │
# │ training_iteration                                 10 │
# │ acc                                           0.65556 │
# │ loss                                           0.5961 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_7ca5815a started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_7ca5815a config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00031 │
# ╰───────────────────────────────────────────────────────╯
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5642, TrainAcc : 0.7193
# (objective_optimizer pid=2839) ValLoss : 0.5961, ValAcc : 0.6556
# 100%|██████████| 10/10 [01:37<00:00,  9.80s/it]
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=2839) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
# (objective_optimizer pid=2839) Epoch : 0
# (objective_optimizer pid=2839) TrainLoss : 0.8716, TrainAcc : 0.6006
# (objective_optimizer pid=2839) ValLoss : 1.0366, ValAcc : 0.5444
#  10%|█         | 1/10 [00:10<01:30, 10.03s/it]
#
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 05:33:54. Total running time: 48min 35s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c612c672 with loss=0.5393751760323843 and params={'lr': 0.00032537224885116194}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7ca5815a   RUNNING      0.000305479        1            10.9874   1.0366     0.544444 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
# (objective_optimizer pid=2839) Epoch : 1
# (objective_optimizer pid=2839) TrainLoss : 0.6015, TrainAcc : 0.6662
# (objective_optimizer pid=2839) ValLoss : 7.6935, ValAcc : 0.6222
#  20%|██        | 2/10 [00:20<01:20, 10.10s/it]
# (objective_optimizer pid=2839) Epoch : 2
# (objective_optimizer pid=2839) TrainLoss : 0.6103, TrainAcc : 0.7123
# (objective_optimizer pid=2839) ValLoss : 0.7270, ValAcc : 0.6944
#  30%|███       | 3/10 [00:29<01:08,  9.78s/it]
# (objective_optimizer pid=2839) Epoch : 3
# (objective_optimizer pid=2839) TrainLoss : 0.5906, TrainAcc : 0.6969
# (objective_optimizer pid=2839) ValLoss : 0.6171, ValAcc : 0.6833
#  40%|████      | 4/10 [00:39<00:58,  9.81s/it]
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 05:34:24. Total running time: 49min 5s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c612c672 with loss=0.5393751760323843 and params={'lr': 0.00032537224885116194}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7ca5815a   RUNNING      0.000305479        4            40.3767   0.617102   0.683333 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
# (objective_optimizer pid=2839) Epoch : 4
# (objective_optimizer pid=2839) TrainLoss : 0.6089, TrainAcc : 0.6872
# (objective_optimizer pid=2839) ValLoss : 0.5784, ValAcc : 0.7222
#  50%|█████     | 5/10 [00:49<00:49,  9.93s/it]
# (objective_optimizer pid=2839) Epoch : 5
# (objective_optimizer pid=2839) TrainLoss : 0.5646, TrainAcc : 0.7109
# (objective_optimizer pid=2839) ValLoss : 0.6232, ValAcc : 0.6611
#  60%|██████    | 6/10 [00:59<00:39,  9.84s/it]
# (objective_optimizer pid=2839) Epoch : 6
# (objective_optimizer pid=2839) TrainLoss : 0.5851, TrainAcc : 0.7011
# (objective_optimizer pid=2839) ValLoss : 0.6077, ValAcc : 0.6444
#  70%|███████   | 7/10 [01:08<00:29,  9.77s/it]
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 05:34:54. Total running time: 49min 35s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c612c672 with loss=0.5393751760323843 and params={'lr': 0.00032537224885116194}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7ca5815a   RUNNING      0.000305479        7            69.8151   0.607655   0.644444 │
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351    0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216   0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142    0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428   0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587   0.576959   0.716667 │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
# (objective_optimizer pid=2839) Epoch : 7
# (objective_optimizer pid=2839) TrainLoss : 0.5533, TrainAcc : 0.7123
# (objective_optimizer pid=2839) ValLoss : 0.5805, ValAcc : 0.6944
#  80%|████████  | 8/10 [01:19<00:19,  9.89s/it]
# (objective_optimizer pid=2839) Epoch : 8
# (objective_optimizer pid=2839) TrainLoss : 0.5496, TrainAcc : 0.6997
# (objective_optimizer pid=2839) ValLoss : 0.5786, ValAcc : 0.7222
#  90%|█████████ | 9/10 [01:28<00:09,  9.89s/it]
#
# Trial objective_optimizer_7ca5815a completed after 10 iterations at 2023-12-30 05:35:15. Total running time: 49min 56s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_7ca5815a result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                                9.541 │
# │ time_total_s                                  99.3709 │
# │ training_iteration                                 10 │
# │ acc                                           0.70556 │
# │ loss                                           0.6153 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial status: 30 TERMINATED
# Current time: 2023-12-30 05:35:15. Total running time: 49min 56s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: c612c672 with loss=0.5393751760323843 and params={'lr': 0.00032537224885116194}
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)        loss        acc │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_00c1eb26   TERMINATED   0.000417216       10           101.351     0.592503   0.694444 │
# │ objective_optimizer_c66de804   TERMINATED   0.00345513        10            99.2216    0.679436   0.65     │
# │ objective_optimizer_a5f78fcb   TERMINATED   0.00780373        10           101.142     0.768166   0.688889 │
# │ objective_optimizer_21a8c299   TERMINATED   0.00100933        10            99.8428    0.631848   0.677778 │
# │ objective_optimizer_24dae463   TERMINATED   0.000274307       10            95.9587    0.576959   0.716667 │
# │ objective_optimizer_70d8affe   TERMINATED   0.00246716        10           100.408     0.646632   0.694444 │
# │ objective_optimizer_394c66c8   TERMINATED   0.000270711       10           100.482     0.599333   0.694444 │
# │ objective_optimizer_3ceace58   TERMINATED   0.00116615        10            99.4435    0.774144   0.661111 │
# │ objective_optimizer_1b4ef96e   TERMINATED   0.00161668        10           101.308     0.610688   0.7      │
# │ objective_optimizer_0449f150   TERMINATED   0.00709579        10            99.6835   14.897      0.594444 │
# │ objective_optimizer_65a057f5   TERMINATED   0.00157687        10            99.4017    0.623647   0.672222 │
# │ objective_optimizer_bd0b996a   TERMINATED   0.000104923       10            99.7343    0.625819   0.672222 │
# │ objective_optimizer_55816244   TERMINATED   0.000284628       10            99.5474    0.68583    0.666667 │
# │ objective_optimizer_1655090d   TERMINATED   0.000420558       10            99.1268    0.665593   0.616667 │
# │ objective_optimizer_8ce8862b   TERMINATED   0.000429412       10           101.315     0.577057   0.705556 │
# │ objective_optimizer_b473d270   TERMINATED   0.000515342       10            98.9715    0.624013   0.672222 │
# │ objective_optimizer_1cb0e6e6   TERMINATED   0.000118191       10            99.8633    0.649972   0.616667 │
# │ objective_optimizer_20786d59   TERMINATED   0.000118915       10           100.008     0.580986   0.716667 │
# │ objective_optimizer_9c2362f2   TERMINATED   0.000201975       10            99.6183    0.612523   0.638889 │
# │ objective_optimizer_5b907da9   TERMINATED   0.000216408       10            99.3999    0.631987   0.638889 │
# │ objective_optimizer_bbaccd1c   TERMINATED   0.000663945       10            98.131     0.611691   0.677778 │
# │ objective_optimizer_09572971   TERMINATED   0.000656686       10            98.776     0.589613   0.688889 │
# │ objective_optimizer_2dc80b76   TERMINATED   0.00016005        10            99.106     0.576991   0.694444 │
# │ objective_optimizer_4e9add37   TERMINATED   0.00014137        10            99.4192    0.595662   0.716667 │
# │ objective_optimizer_e9ad467c   TERMINATED   0.000185523       10            98.9093    0.578097   0.683333 │
# │ objective_optimizer_4ba1f706   TERMINATED   0.000182385       10            99.0544    0.574745   0.716667 │
# │ objective_optimizer_c612c672   TERMINATED   0.000325372       10           101.256     0.539375   0.727778 │
# │ objective_optimizer_92bfc42b   TERMINATED   0.000291634       10            98.6429    0.620899   0.611111 │
# │ objective_optimizer_5a767db4   TERMINATED   0.000317483       10            99.126     0.596097   0.655556 │
# │ objective_optimizer_7ca5815a   TERMINATED   0.000305479       10            99.3709    0.615304   0.705556 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# (objective_optimizer pid=2839) Epoch : 9
# (objective_optimizer pid=2839) TrainLoss : 0.5525, TrainAcc : 0.7207
# (objective_optimizer pid=2839) ValLoss : 0.6153, ValAcc : 0.7056
# 100%|██████████| 10/10 [01:38<00:00,  9.84s/it]
# Best Configuration:  {'lr': 0.00032537224885116194}

# %%
# !python DownloadFromColab.py -p="/root/ray_results"
# Out:
# Enjoy...
