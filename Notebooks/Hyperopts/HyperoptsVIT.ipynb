# %%
# !git clone https://github.com/VosLannuck/UnderstandingYou_
# %cd UnderstandingYou_
# Out:
# Cloning into 'UnderstandingYou_'...
# remote: Enumerating objects: 1377, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 1377 (delta 148), reused 244 (delta 148), pack-reused 1133
# Receiving objects: 100% (1377/1377), 64.81 MiB | 24.02 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/UnderstandingYou_

# %%
# !pip install -r requirements.txt
# Out:
# Collecting matplotlib==3.7.2 (from -r requirements.txt (line 1))
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 31.5 MB/s eta 0:00:00
# Collecting mlflow==2.8.1 (from -r requirements.txt (line 2))
#   Downloading mlflow-2.8.1-py3-none-any.whl (19.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 72.1 MB/s eta 0:00:00
# Collecting numpy==1.24.3 (from -r requirements.txt (line 3))
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 72.2 MB/s eta 0:00:00
# Collecting omegaconf==2.3.0 (from -r requirements.txt (line 4))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 13.6 MB/s eta 0:00:00
# Collecting pandas==2.0.3 (from -r requirements.txt (line 5))
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 103.6 MB/s eta 0:00:00
# Collecting Pillow==10.1.0 (from -r requirements.txt (line 6))
#   Downloading Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 51.0 MB/s eta 0:00:00
# Collecting ray==2.8.1 (from -r requirements.txt (line 7))
#   Downloading ray-2.8.1-cp310-cp310-manylinux2014_x86_64.whl (62.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (1.11.4)
# Collecting torch==2.1.1 (from -r requirements.txt (line 9))
#   Downloading torch-2.1.1-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: torchsummary==1.5.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (1.5.1)
# Collecting torchvision==0.16.1 (from -r requirements.txt (line 11))
#   Downloading torchvision-0.16.1-cp310-cp310-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 81.0 MB/s eta 0:00:00
# Collecting tqdm==4.65.0 (from -r requirements.txt (line 12))
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 10.3 MB/s eta 0:00:00
# Collecting optuna==3.5.0 (from -r requirements.txt (line 13))
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 44.4 MB/s eta 0:00:00
# Collecting tensorboardX==2.5.0 (from -r requirements.txt (line 14))
#   Downloading tensorboardX-2.5-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (23.2)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib==3.7.2->-r requirements.txt (line 1))
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.2->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.2.1)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.31.0)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 27.6 MB/s eta 0:00:00
# Collecting docker<7,>=4.0.0 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.2.5)
# Collecting querystring-parser<2 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (2.0.23)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pyarrow<15,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (10.0.1)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.5.1)
# Collecting gunicorn<22 (from mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.8.1->-r requirements.txt (line 2)) (3.1.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf==2.3.0->-r requirements.txt (line 4))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tzdata>=2022.1 (from pandas==2.0.3->-r requirements.txt (line 5))
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray==2.8.1->-r requirements.txt (line 7)) (1.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (3.2.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 65.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 70.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 101.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.1->-r requirements.txt (line 9)) (2.1.0)
# Collecting colorlog (from optuna==3.5.0->-r requirements.txt (line 13))
#   Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorboardX==2.5.0->-r requirements.txt (line 14)) (1.16.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.1->-r requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 62.1 MB/s eta 0:00:00
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.8.1->-r requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow==2.8.1->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow==2.8.1->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<4->mlflow==2.8.1->-r requirements.txt (line 2)) (2.1.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.8.1->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow==2.8.1->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.8.1->-r requirements.txt (line 2)) (2023.11.17)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.8.1->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.8.1->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.8.1->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray==2.8.1->-r requirements.txt (line 7)) (0.15.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.1->-r requirements.txt (line 9)) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.8.1->-r requirements.txt (line 2))
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=232a0d6bb54d76f5987f9ec558f909b7f5715abd61a579cb47f5f2bea31817af
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, tzdata, tqdm, smmap, querystring-parser, pyparsing, Pillow, omegaconf, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, Mako, importlib-metadata, gunicorn, colorlog, tensorboardX, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb, docker, databricks-cli, alembic, optuna, nvidia-cusolver-cu12, matplotlib, gitpython, torch, ray, mlflow, torchvision
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.0
#     Uninstalling importlib-metadata-7.0.0:
#       Successfully uninstalled importlib-metadata-7.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu121
#     Uninstalling torch-2.1.0+cu121:
#       Successfully uninstalled torch-2.1.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0+cu121
#     Uninstalling torchvision-0.16.0+cu121:
#       Successfully uninstalled torchvision-0.16.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.0.3 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 2.1.1 which is incompatible.
# Successfully installed Mako-1.3.0 Pillow-10.1.0 alembic-1.13.1 antlr4-python3-runtime-4.9.3 colorlog-6.8.0 databricks-cli-0.18.0 docker-6.1.3 gitdb-4.0.11 gitpython-3.1.40 gunicorn-21.2.0 importlib-metadata-6.11.0 matplotlib-3.7.2 mlflow-2.8.1 numpy-1.24.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 omegaconf-2.3.0 optuna-3.5.0 pandas-2.0.3 pyparsing-3.0.9 querystring-parser-1.2.4 ray-2.8.1 smmap-5.0.1 tensorboardX-2.5 torch-2.1.1 torchvision-0.16.1 tqdm-4.65.0 tzdata-2023.4

# %%
# !python HyperparamsMain.py -m="vit_swin"
# Out:
# Streaming output truncated to the last 5000 lines.
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7fae87fd   RUNNING      0.00022908         5            92.8935   0.651436   0.666667 │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_33906c35   PENDING      0.00851449                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  60%|██████    | 6/10 [01:49<01:13, 18.31s/it]
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.6398, TrainAcc : 0.6550
# (objective_optimizer pid=1895) ValLoss : 0.6182, ValAcc : 0.6611
# Trial status: 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:30:58. Total running time: 5min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.6172133088111877 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7fae87fd   RUNNING      0.00022908         7            129.711   0.617213   0.661111 │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_33906c35   PENDING      0.00851449                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  80%|████████  | 8/10 [02:26<00:36, 18.22s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.5873, TrainAcc : 0.7025
# (objective_optimizer pid=1895) ValLoss : 0.5856, ValAcc : 0.7167
#  90%|█████████ | 9/10 [02:44<00:18, 18.14s/it]
# (objective_optimizer pid=1895) Epoch : 8
# (objective_optimizer pid=1895) TrainLoss : 0.5641, TrainAcc : 0.7081
# (objective_optimizer pid=1895) ValLoss : 0.5114, ValAcc : 0.7222
# Trial status: 1 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:31:28. Total running time: 6min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5113858381907145 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7fae87fd   RUNNING      0.00022908         9            165.596   0.511386   0.722222 │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_33906c35   PENDING      0.00851449                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_7fae87fd completed after 10 iterations at 2023-12-30 05:31:40. Total running time: 6min 13s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_7fae87fd result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              18.2776 │
# │ time_total_s                                  183.874 │
# │ training_iteration                                 10 │
# │ acc                                           0.76667 │
# │ loss                                          0.53673 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_33906c35 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_33906c35 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00851 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [03:02<00:00, 18.25s/it]
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.5543, TrainAcc : 0.7346
# (objective_optimizer pid=1895) ValLoss : 0.5367, ValAcc : 0.7667
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:31:58. Total running time: 6min 30s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449                                                    │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  10%|█         | 1/10 [00:18<02:44, 18.24s/it]
# (objective_optimizer pid=1895) Epoch : 0
# (objective_optimizer pid=1895) TrainLoss : 1.1973, TrainAcc : 0.5098
# (objective_optimizer pid=1895) ValLoss : 0.6951, ValAcc : 0.5000
#  20%|██        | 2/10 [00:36<02:24, 18.03s/it]
# (objective_optimizer pid=1895) Epoch : 1
# (objective_optimizer pid=1895) TrainLoss : 0.8487, TrainAcc : 0.4818
# (objective_optimizer pid=1895) ValLoss : 0.7371, ValAcc : 0.5000
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:32:28. Total running time: 7min 0s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449         2             38.524   0.737092   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  30%|███       | 3/10 [00:54<02:06, 18.02s/it]
# (objective_optimizer pid=1895) Epoch : 2
# (objective_optimizer pid=1895) TrainLoss : 0.8271, TrainAcc : 0.5070
# (objective_optimizer pid=1895) ValLoss : 0.7089, ValAcc : 0.5000
#  40%|████      | 4/10 [01:12<01:49, 18.26s/it]
# (objective_optimizer pid=1895) Epoch : 3
# (objective_optimizer pid=1895) TrainLoss : 0.7490, TrainAcc : 0.5237
# (objective_optimizer pid=1895) ValLoss : 0.7008, ValAcc : 0.5000
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:32:58. Total running time: 7min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449         4            75.1504   0.700755   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  50%|█████     | 5/10 [01:30<01:31, 18.24s/it]
# (objective_optimizer pid=1895) Epoch : 4
# (objective_optimizer pid=1895) TrainLoss : 0.7367, TrainAcc : 0.5014
# (objective_optimizer pid=1895) ValLoss : 0.6932, ValAcc : 0.5000
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:33:28. Total running time: 8min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449         5            93.3615   0.693183   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  60%|██████    | 6/10 [01:48<01:12, 18.17s/it]
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.7188, TrainAcc : 0.5000
# (objective_optimizer pid=1895) ValLoss : 0.6932, ValAcc : 0.4944
#  70%|███████   | 7/10 [02:07<00:54, 18.13s/it]
# (objective_optimizer pid=1895) Epoch : 6
# (objective_optimizer pid=1895) TrainLoss : 0.6962, TrainAcc : 0.5391
# (objective_optimizer pid=1895) ValLoss : 0.7518, ValAcc : 0.5000
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:33:58. Total running time: 8min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449         7            129.429   0.751842   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  80%|████████  | 8/10 [02:25<00:36, 18.36s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.7331, TrainAcc : 0.5265
# (objective_optimizer pid=1895) ValLoss : 0.7112, ValAcc : 0.5000
#  90%|█████████ | 9/10 [02:44<00:18, 18.34s/it]
# (objective_optimizer pid=1895) Epoch : 8
# (objective_optimizer pid=1895) TrainLoss : 0.7129, TrainAcc : 0.4832
# (objective_optimizer pid=1895) ValLoss : 0.7002, ValAcc : 0.5000
# Trial status: 2 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:34:28. Total running time: 9min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_33906c35   RUNNING      0.00851449         9            166.555   0.700208   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_3a83aa0c   PENDING      0.00039335                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_33906c35 completed after 10 iterations at 2023-12-30 05:34:45. Total running time: 9min 18s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_33906c35 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                               17.979 │
# │ time_total_s                                  184.534 │
# │ training_iteration                                 10 │
# │ acc                                               0.5 │
# │ loss                                          0.69315 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_3a83aa0c started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_3a83aa0c config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00039 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [03:02<00:00, 18.22s/it]
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.6966, TrainAcc : 0.5209
# (objective_optimizer pid=1895) ValLoss : 0.6931, ValAcc : 0.5000
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:34:58. Total running time: 9min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335                                                    │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=1895) Epoch : 0
# (objective_optimizer pid=1895) TrainLoss : 0.7351, TrainAcc : 0.4930
# (objective_optimizer pid=1895) ValLoss : 0.7130, ValAcc : 0.5000
#  10%|█         | 1/10 [00:18<02:45, 18.34s/it]
#  20%|██        | 2/10 [00:36<02:27, 18.47s/it]
# (objective_optimizer pid=1895) Epoch : 1
# (objective_optimizer pid=1895) TrainLoss : 0.7045, TrainAcc : 0.4874
# (objective_optimizer pid=1895) ValLoss : 0.7063, ValAcc : 0.5000
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:35:28. Total running time: 10min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335         2            38.3888   0.706304   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  30%|███       | 3/10 [00:54<02:07, 18.20s/it]
# (objective_optimizer pid=1895) Epoch : 2
# (objective_optimizer pid=1895) TrainLoss : 0.7083, TrainAcc : 0.5140
# (objective_optimizer pid=1895) ValLoss : 0.7062, ValAcc : 0.5000
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:35:58. Total running time: 10min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335         3            56.2673   0.70625    0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  40%|████      | 4/10 [01:12<01:48, 18.02s/it]
# (objective_optimizer pid=1895) Epoch : 3
# (objective_optimizer pid=1895) TrainLoss : 0.6979, TrainAcc : 0.4958
# (objective_optimizer pid=1895) ValLoss : 0.6839, ValAcc : 0.5222
#  50%|█████     | 5/10 [01:30<01:30, 18.05s/it]
# (objective_optimizer pid=1895) Epoch : 4
# (objective_optimizer pid=1895) TrainLoss : 0.6907, TrainAcc : 0.5573
# (objective_optimizer pid=1895) ValLoss : 0.6817, ValAcc : 0.5000
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:36:28. Total running time: 11min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335         5             92.098   0.681697   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.6713, TrainAcc : 0.6006
# (objective_optimizer pid=1895) ValLoss : 0.6324, ValAcc : 0.6778
#  60%|██████    | 6/10 [01:49<01:12, 18.24s/it]
#  70%|███████   | 7/10 [02:07<00:54, 18.13s/it]
# (objective_optimizer pid=1895) Epoch : 6
# (objective_optimizer pid=1895) TrainLoss : 0.6685, TrainAcc : 0.6117
# (objective_optimizer pid=1895) ValLoss : 0.6396, ValAcc : 0.6722
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:36:58. Total running time: 11min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335         7            128.62    0.639636   0.672222 │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  80%|████████  | 8/10 [02:25<00:36, 18.04s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.6937, TrainAcc : 0.5894
# (objective_optimizer pid=1895) ValLoss : 0.6658, ValAcc : 0.6333
# Trial status: 3 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:37:28. Total running time: 12min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_3a83aa0c   RUNNING      0.00039335         8            146.474   0.665838   0.633333 │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_a5cbe2c0   PENDING      0.00123306                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  90%|█████████ | 9/10 [02:43<00:18, 18.05s/it]
# (objective_optimizer pid=1895) Epoch : 8
# (objective_optimizer pid=1895) TrainLoss : 0.6493, TrainAcc : 0.6480
# (objective_optimizer pid=1895) ValLoss : 0.6308, ValAcc : 0.6278
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.6713, TrainAcc : 0.6117
# (objective_optimizer pid=1895) ValLoss : 0.6640, ValAcc : 0.5889
#
# Trial objective_optimizer_3a83aa0c completed after 10 iterations at 2023-12-30 05:37:48. Total running time: 12min 21s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_3a83aa0c result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              18.8666 │
# │ time_total_s                                  183.386 │
# │ training_iteration                                 10 │
# │ acc                                           0.58889 │
# │ loss                                          0.66403 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_a5cbe2c0 started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_a5cbe2c0 config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00123 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [03:01<00:00, 18.19s/it]
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:37:58. Total running time: 12min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306                                                    │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  10%|█         | 1/10 [00:17<02:38, 17.60s/it]
# (objective_optimizer pid=1895) Epoch : 0
# (objective_optimizer pid=1895) TrainLoss : 0.8102, TrainAcc : 0.4944
# (objective_optimizer pid=1895) ValLoss : 0.7019, ValAcc : 0.5000
#  20%|██        | 2/10 [00:35<02:21, 17.65s/it]
# (objective_optimizer pid=1895) Epoch : 1
# (objective_optimizer pid=1895) TrainLoss : 0.7037, TrainAcc : 0.4944
# (objective_optimizer pid=1895) ValLoss : 0.6995, ValAcc : 0.5000
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:38:28. Total running time: 13min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306         2            36.5777   0.699547   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  30%|███       | 3/10 [00:53<02:04, 17.76s/it]
# (objective_optimizer pid=1895) Epoch : 2
# (objective_optimizer pid=1895) TrainLoss : 0.7061, TrainAcc : 0.4888
# (objective_optimizer pid=1895) ValLoss : 0.6952, ValAcc : 0.5000
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:38:59. Total running time: 13min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306         3            54.4613   0.695181   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  40%|████      | 4/10 [01:11<01:48, 18.02s/it]
# (objective_optimizer pid=1895) Epoch : 3
# (objective_optimizer pid=1895) TrainLoss : 0.6983, TrainAcc : 0.4958
# (objective_optimizer pid=1895) ValLoss : 0.6971, ValAcc : 0.5000
#  50%|█████     | 5/10 [01:29<01:29, 17.87s/it]
# (objective_optimizer pid=1895) Epoch : 4
# (objective_optimizer pid=1895) TrainLoss : 0.6969, TrainAcc : 0.5251
# (objective_optimizer pid=1895) ValLoss : 0.6950, ValAcc : 0.5000
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:39:29. Total running time: 14min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306         5            90.4647   0.695005   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.7016, TrainAcc : 0.4986
# (objective_optimizer pid=1895) ValLoss : 0.6981, ValAcc : 0.5000
#  60%|██████    | 6/10 [01:47<01:12, 18.15s/it]
#  70%|███████   | 7/10 [02:05<00:54, 18.11s/it]
# (objective_optimizer pid=1895) Epoch : 6
# (objective_optimizer pid=1895) TrainLoss : 0.6916, TrainAcc : 0.5140
# (objective_optimizer pid=1895) ValLoss : 0.6988, ValAcc : 0.5000
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:39:59. Total running time: 14min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306         7            127.188   0.698768   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  80%|████████  | 8/10 [02:24<00:36, 18.18s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.7049, TrainAcc : 0.5014
# (objective_optimizer pid=1895) ValLoss : 0.7037, ValAcc : 0.5000
# Trial status: 4 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:40:29. Total running time: 15min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_a5cbe2c0   RUNNING      0.00123306         8            145.513   0.703651   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_9c02a3ee   PENDING      0.00207897                                                    │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  90%|█████████ | 9/10 [02:41<00:17, 17.97s/it]
# (objective_optimizer pid=1895) Epoch : 8
# (objective_optimizer pid=1895) TrainLoss : 0.7000, TrainAcc : 0.5237
# (objective_optimizer pid=1895) ValLoss : 0.6966, ValAcc : 0.5000
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.6979, TrainAcc : 0.5014
# (objective_optimizer pid=1895) ValLoss : 0.6948, ValAcc : 0.5000
#
# Trial objective_optimizer_a5cbe2c0 completed after 10 iterations at 2023-12-30 05:40:49. Total running time: 15min 22s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_a5cbe2c0 result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                              17.6207 │
# │ time_total_s                                  180.638 │
# │ training_iteration                                 10 │
# │ acc                                               0.5 │
# │ loss                                          0.69478 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial objective_optimizer_9c02a3ee started with configuration:
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_9c02a3ee config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00208 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [02:59<00:00, 17.94s/it]
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:40:59. Total running time: 15min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897                                                    │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# │ objective_optimizer_53ba9b4b   PENDING      0.000154648                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  10%|█         | 1/10 [00:18<02:42, 18.01s/it]
# (objective_optimizer pid=1895) Epoch : 0
# (objective_optimizer pid=1895) TrainLoss : 0.8741, TrainAcc : 0.4958
# (objective_optimizer pid=1895) ValLoss : 0.7156, ValAcc : 0.5000
#  20%|██        | 2/10 [00:36<02:25, 18.23s/it]
# (objective_optimizer pid=1895) Epoch : 1
# (objective_optimizer pid=1895) TrainLoss : 0.7192, TrainAcc : 0.4818
# (objective_optimizer pid=1895) ValLoss : 0.6946, ValAcc : 0.5000
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:41:29. Total running time: 16min 1s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897         2            37.7941   0.694576   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# │ objective_optimizer_53ba9b4b   PENDING      0.000154648                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  30%|███       | 3/10 [00:53<02:05, 17.94s/it]
# (objective_optimizer pid=1895) Epoch : 2
# (objective_optimizer pid=1895) TrainLoss : 0.7069, TrainAcc : 0.5084
# (objective_optimizer pid=1895) ValLoss : 0.6938, ValAcc : 0.5000
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:41:59. Total running time: 16min 31s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897         3            55.3889   0.693804   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# │ objective_optimizer_53ba9b4b   PENDING      0.000154648                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  40%|████      | 4/10 [01:11<01:47, 17.85s/it]
# (objective_optimizer pid=1895) Epoch : 3
# (objective_optimizer pid=1895) TrainLoss : 0.7118, TrainAcc : 0.5126
# (objective_optimizer pid=1895) ValLoss : 0.7004, ValAcc : 0.5000
#  50%|█████     | 5/10 [01:29<01:28, 17.79s/it]
# (objective_optimizer pid=1895) Epoch : 4
# (objective_optimizer pid=1895) TrainLoss : 0.6940, TrainAcc : 0.5321
# (objective_optimizer pid=1895) ValLoss : 0.7025, ValAcc : 0.5000
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:42:29. Total running time: 17min 2s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897         5            90.7946   0.702486   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# │ objective_optimizer_53ba9b4b   PENDING      0.000154648                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  60%|██████    | 6/10 [01:47<01:11, 17.93s/it]
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.7037, TrainAcc : 0.4986
# (objective_optimizer pid=1895) ValLoss : 0.7029, ValAcc : 0.5000
#  70%|███████   | 7/10 [02:05<00:53, 17.86s/it]
# (objective_optimizer pid=1895) Epoch : 6
# (objective_optimizer pid=1895) TrainLoss : 0.7003, TrainAcc : 0.4888
# (objective_optimizer pid=1895) ValLoss : 0.6933, ValAcc : 0.5000
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:42:59. Total running time: 17min 32s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897         7            126.705   0.693288   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# │ objective_optimizer_53ba9b4b   PENDING      0.000154648                                                   │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#  80%|████████  | 8/10 [02:22<00:35, 17.77s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.7128, TrainAcc : 0.4874
# (objective_optimizer pid=1895) ValLoss : 0.6932, ValAcc : 0.5000
# Trial status: 5 TERMINATED | 1 RUNNING | 1 PENDING
# Current time: 2023-12-30 05:43:29. Total running time: 18min 2s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: 7fae87fd with loss=0.5367252031962076 and params={'lr': 0.00022907978435445024}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_9c02a3ee   RUNNING      0.00207897         8            144.261   0.693233   0.5      │
# ...
# │ Trial objective_optimizer_7b52e68a config             │
# ├───────────────────────────────────────────────────────┤
# │ lr                                            0.00058 │
# ╰───────────────────────────────────────────────────────╯
# 100%|██████████| 10/10 [03:01<00:00, 18.17s/it]
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.6429, TrainAcc : 0.6858
# (objective_optimizer pid=1895) ValLoss : 0.6580, ValAcc : 0.6167
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Training/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Validation/
# (objective_optimizer pid=1895) /content/UnderstandingYou_/Dataset/Testing/
#   0%|          | 0/10 [00:00<?, ?it/s]
#
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:53:37. Total running time: 1hr 28min 9s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895                                                   │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  10%|█         | 1/10 [00:17<02:40, 17.83s/it]
# (objective_optimizer pid=1895) Epoch : 0
# (objective_optimizer pid=1895) TrainLoss : 0.8196, TrainAcc : 0.5182
# (objective_optimizer pid=1895) ValLoss : 0.7715, ValAcc : 0.5000
# (objective_optimizer pid=1895) Epoch : 1
# (objective_optimizer pid=1895) TrainLoss : 0.7165, TrainAcc : 0.4637
# (objective_optimizer pid=1895) ValLoss : 0.6957, ValAcc : 0.5000
#  20%|██        | 2/10 [00:35<02:23, 17.89s/it]
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:54:07. Total running time: 1hr 28min 40s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895        2            37.1028   0.695745   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  30%|███       | 3/10 [00:55<02:10, 18.58s/it]
# (objective_optimizer pid=1895) Epoch : 2
# (objective_optimizer pid=1895) TrainLoss : 0.7007, TrainAcc : 0.5000
# (objective_optimizer pid=1895) ValLoss : 0.6953, ValAcc : 0.5000
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:54:37. Total running time: 1hr 29min 10s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895        3            56.5133   0.695323   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  40%|████      | 4/10 [01:12<01:49, 18.26s/it]
# (objective_optimizer pid=1895) Epoch : 3
# (objective_optimizer pid=1895) TrainLoss : 0.7012, TrainAcc : 0.5028
# (objective_optimizer pid=1895) ValLoss : 0.6951, ValAcc : 0.5000
#  50%|█████     | 5/10 [01:30<01:30, 18.06s/it]
# (objective_optimizer pid=1895) Epoch : 4
# (objective_optimizer pid=1895) TrainLoss : 0.7035, TrainAcc : 0.4763
# (objective_optimizer pid=1895) ValLoss : 0.6939, ValAcc : 0.5000
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:55:07. Total running time: 1hr 29min 40s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895        5            91.9833   0.693927   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10           183.882    0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10           183.874    0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10           184.534    0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10           183.386    0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10           180.638    0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  60%|██████    | 6/10 [01:48<01:12, 18.07s/it]
# (objective_optimizer pid=1895) Epoch : 5
# (objective_optimizer pid=1895) TrainLoss : 0.7005, TrainAcc : 0.4832
# (objective_optimizer pid=1895) ValLoss : 0.6931, ValAcc : 0.5000
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:55:37. Total running time: 1hr 30min 10s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895        6            110.06    0.693103   0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  70%|███████   | 7/10 [02:06<00:54, 18.12s/it]
# (objective_optimizer pid=1895) Epoch : 6
# (objective_optimizer pid=1895) TrainLoss : 0.7029, TrainAcc : 0.4777
# (objective_optimizer pid=1895) ValLoss : 0.6944, ValAcc : 0.5000
#  80%|████████  | 8/10 [02:24<00:36, 18.01s/it]
# (objective_optimizer pid=1895) Epoch : 7
# (objective_optimizer pid=1895) TrainLoss : 0.6960, TrainAcc : 0.5014
# (objective_optimizer pid=1895) ValLoss : 0.6931, ValAcc : 0.5000
# Trial status: 29 TERMINATED | 1 RUNNING
# Current time: 2023-12-30 06:56:07. Total running time: 1hr 30min 40s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_7b52e68a   RUNNING      0.000580895        8            146.046   0.69313    0.5      │
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 24 more TERMINATED
#  90%|█████████ | 9/10 [02:42<00:17, 17.88s/it]
# (objective_optimizer pid=1895) Epoch : 8
# (objective_optimizer pid=1895) TrainLoss : 0.6934, TrainAcc : 0.4972
# (objective_optimizer pid=1895) ValLoss : 0.6931, ValAcc : 0.5000
#
# Trial objective_optimizer_7b52e68a completed after 10 iterations at 2023-12-30 06:56:30. Total running time: 1hr 31min 3s
# ╭───────────────────────────────────────────────────────╮
# │ Trial objective_optimizer_7b52e68a result             │
# ├───────────────────────────────────────────────────────┤
# │ checkpoint_dir_name                                   │
# │ time_this_iter_s                               17.835 │
# │ time_total_s                                  181.494 │
# │ training_iteration                                 10 │
# │ acc                                               0.5 │
# │ loss                                          0.69318 │
# ╰───────────────────────────────────────────────────────╯
#
# Trial status: 30 TERMINATED
# Current time: 2023-12-30 06:56:30. Total running time: 1hr 31min 3s
# Logical resource usage: 2.0/2 CPUs, 1.0/1 GPUs
# Current best trial: d3d87f38 with loss=0.2610109547773997 and params={'lr': 0.00010365450490949438}
# ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name                     status                lr     iter     total time (s)       loss        acc │
# ├───────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ objective_optimizer_8363082f   TERMINATED   0.000400185       10            183.882   0.692853   0.5      │
# │ objective_optimizer_7fae87fd   TERMINATED   0.00022908        10            183.874   0.536725   0.766667 │
# │ objective_optimizer_33906c35   TERMINATED   0.00851449        10            184.534   0.693148   0.5      │
# │ objective_optimizer_3a83aa0c   TERMINATED   0.00039335        10            183.386   0.664028   0.588889 │
# │ objective_optimizer_a5cbe2c0   TERMINATED   0.00123306        10            180.638   0.694777   0.5      │
# │ objective_optimizer_9c02a3ee   TERMINATED   0.00207897        10            180.041   0.693207   0.5      │
# │ objective_optimizer_53ba9b4b   TERMINATED   0.000154648       10            182.956   0.331881   0.844444 │
# │ objective_optimizer_40746c39   TERMINATED   0.0064607         10            183.307   0.703529   0.5      │
# │ objective_optimizer_667462df   TERMINATED   0.00864959        10            182.193   0.702824   0.5      │
# │ objective_optimizer_7d3f4045   TERMINATED   0.00289702        10            182.732   0.694572   0.5      │
# │ objective_optimizer_f9a7835b   TERMINATED   0.00332582        10            178.058   0.694399   0.5      │
# │ objective_optimizer_f4f1f514   TERMINATED   0.000114511       10            184.144   0.369558   0.838889 │
# │ objective_optimizer_4bf10fab   TERMINATED   0.000141539       10            181.777   0.422796   0.8      │
# │ objective_optimizer_288bd0c2   TERMINATED   0.00011247        10            182.036   0.309516   0.872222 │
# │ objective_optimizer_d3d87f38   TERMINATED   0.000103655       10            182.648   0.261011   0.916667 │
# │ objective_optimizer_7db3fd65   TERMINATED   0.000478854       10            180.387   0.692999   0.5      │
# │ objective_optimizer_ee75577c   TERMINATED   0.000414679       10            182.817   0.639551   0.638889 │
# │ objective_optimizer_4b14b6b1   TERMINATED   0.000277576       10            180.231   0.75665    0.588889 │
# │ objective_optimizer_f0cff49b   TERMINATED   0.000208763       10            179.838   0.472861   0.772222 │
# │ objective_optimizer_378ffc51   TERMINATED   0.000107136       10            180.937   0.45491    0.811111 │
# │ objective_optimizer_ccd3de44   TERMINATED   0.000795895       10            177.439   0.693165   0.5      │
# │ objective_optimizer_2bf1344f   TERMINATED   0.000775175       10            181.794   0.693435   0.5      │
# │ objective_optimizer_2819656d   TERMINATED   0.000170456       10            183.191   0.346173   0.85     │
# │ objective_optimizer_d2517a59   TERMINATED   0.000162858       10            181.906   0.469806   0.788889 │
# │ objective_optimizer_d272721e   TERMINATED   0.000106949       10            179.075   0.469916   0.783333 │
# │ objective_optimizer_5d96cb0d   TERMINATED   0.000110918       10            182.868   0.325922   0.861111 │
# │ objective_optimizer_dac3b6b2   TERMINATED   0.00027935        10            184.699   0.622028   0.7      │
# │ objective_optimizer_28eb738c   TERMINATED   0.000274128       10            179.942   0.689487   0.511111 │
# │ objective_optimizer_04519894   TERMINATED   0.000295957       10            183.153   0.658001   0.616667 │
# │ objective_optimizer_7b52e68a   TERMINATED   0.000580895       10            181.494   0.693184   0.5      │
# ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# 100%|██████████| 10/10 [03:00<00:00, 18.02s/it]
# (objective_optimizer pid=1895) Epoch : 9
# (objective_optimizer pid=1895) TrainLoss : 0.6990, TrainAcc : 0.4791
# (objective_optimizer pid=1895) ValLoss : 0.6932, ValAcc : 0.5000
# Best Configuration:  {'lr': 0.00010365450490949438}

# %%
# !python DownloadFromColab.py -p="/root/ray_results/"
# Out:
# Enjoy...
