# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !apt-get install unzip
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/Alex_lr_scheduler_checkpoints.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Alex_lr"
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/Checkpoint_Alex.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Alex"
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/Checkpoint_Resnet.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Resnet"
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/CheckpointVGG16.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extract/VGG16"
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/Resnet_lr_scheduler_checkpoints.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extracta/Resnet_lr"
# !unzip "/content/drive/MyDrive/S2_AIS/Checkpoints/VGG16_lr_scheduler_checkpoints.zip" -d "/content/drive/MyDrive/S2_AIS/Checkpoints_Extract/VGG16_lr"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Archive:  /content/drive/MyDrive/S2_AIS/Checkpoints/Alex_lr_scheduler_checkpoints.zip
# replace /content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Alex_lr/pretrained_alex/last.pth? [y]es, [n]o, [A]ll, [N]one, [r]ename: Archive:  /content/drive/MyDrive/S2_AIS/Checkpoints/Checkpoint_Alex.zip
# Archive:  /content/drive/MyDrive/S2_AIS/Checkpoints/Checkpoint_Resnet.zip
#    creating: /content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Resnet/pretrained_resnet/
#    creating: /content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Resnet/vanilla_resnet/
#   inflating: /content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Resnet/pretrained_resnet/last.pth
#   inflating: /content/drive/MyDrive/S2_AIS/Checkpoints_Extract/Resnet/pretrained_resnet/best.pth
# ...
