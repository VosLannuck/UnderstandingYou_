# %%
# !git clone https://github.com/VosLannuck/UnderstandingYou_.git
# %cd UnderstandingYou_
# Out:
# Cloning into 'UnderstandingYou_'...
# remote: Enumerating objects: 1386, done.
# remote: Counting objects: 100% (253/253), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 1386 (delta 154), reused 252 (delta 153), pack-reused 1133
# Receiving objects: 100% (1386/1386), 66.17 MiB | 31.07 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# /content/UnderstandingYou_

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 48.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 18.3 MB/s eta 0:00:00
# ...

# %%
# !python Main.py -m="vanilla_alex"
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100% 83.3M/83.3M [00:00<00:00, 158MB/s]
# Running with Scheduler
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
# ...

# %%
# !python Main.py -m="pretrained_alex"
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:01<00:00, 153MB/s]
# features.0.weight
# features.0.bias
# features.3.weight
# features.3.bias
# features.6.weight
# features.6.bias
# features.8.weight
# features.8.bias
# features.10.weight
# features.10.bias
# classifier.1.weight
# classifier.1.bias
# classifier.4.weight
# classifier.4.bias
# classifier.6.weight
# classifier.6.bias
# Running with Scheduler
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !python DownloadFromColab.py -p="/content/UnderstandingYou_/checkpoints/"
# Out:
# Enjoy...

# %%
# !mv "/content/UnderstandingYou_/Alex_lr_scheduler_checkpoints.zip" "/content/drive/MyDrive/S2_AIS/Checkpoints"

# %%
# !python DownloadFromColab.py -p="/content/UnderstandingYou_/mlruns/"
# Out:
# Enjoy...

# %%
# !mv "/content/UnderstandingYou_/Alex_lr_scheduler_mlruns.zip" "/content/drive/MyDrive/S2_AIS/mlruns"
